# %%
import subprocess
import sys

def run_script(command):
    """Utility function to run a command and handle errors."""
    print(f"Executing: {' '.join(command)}")
    try:
        # check=True raises an error if the script fails (non-zero exit code)
        subprocess.run(command, check=True)
        print("Success!\n" + "-" * 40)
    except subprocess.CalledProcessError as e:
        print(f"Error occurred while running: {' '.join(command)}")
        sys.exit(e.returncode)

def main():
    print("Starting pipeline...\n" + "=" * 40)

    # --- Early Setup / Initialization Steps ---

    # 1. Compile Ab Initio Configs
    run_script(["python", "scripts_abinitio/compile_abinitio_configs.py"])

    # 2. True Interface Restraints (Oracle)
    run_script(["python", "scripts_oracle/true_interface_restraints.py"])

    # 3. Compile Oracle Configs
    run_script(["python", "scripts_oracle/compile_oracle_configs.py"])

    # --- Main Inference & Evaluation Pipeline ---

    # 4. Inference with ESM3-PPISites large model
    # Input: esm3_reps/db5_embeddings.pt -> Output: inference_results/db5_results.csv
    run_script(["python", "scripts_eval/inferenceESM3.py"])

    # 5. Patches creation
    # Input: inference_results/db5_results.csv -> Output: inference_results/db5_for_pairing.csv
    run_script(["python", "scripts_eval/PATCHES.py"])

    # 6. Pairing patches and patches config file creation
    # Input: inference_results/db5_for_pairing.csv
    # Output: haddock-units/*/tbls and haddock-units/*/configs
    run_script(["python", "scripts_eval/PAIRING.py"])

    print("Pipeline completed successfully!")


if __name__ == "__main__":
    main()
# Out:
# Starting pipeline...
# ========================================
# Executing: python scripts_abinitio/compile_abinitio_configs.py
# Processing unit: 1JK9
#   Found: 1JK9_WZ.pdb, 2JCW_Z.pdb, 1QUP_W.pdb
#   Created configs/config_abinitio.cfg
# Processing unit: 1KXP
#   Found: 1KXP_WZ.pdb, 1KW2_Z.pdb, 1IJJ_W.pdb
#   Created configs/config_abinitio.cfg
# Processing unit: 1US7
#   Found: 1US7_WZ.pdb, 2W0G_Z.pdb, 2FXS_W.pdb
#   Created configs/config_abinitio.cfg
# Processing unit: 1Z5Y
#   Found: 1Z5Y_WZ.pdb, 2B1K_Z.pdb, 1L6P_W.pdb
#   Created configs/config_abinitio.cfg
# Processing unit: 1ZHH
#   Found: 1ZHH_WZ.pdb, 2HJE_Z.pdb, 1JX6_W.pdb
#   Created configs/config_abinitio.cfg
# Processing unit: 1ZHI
#   Found: 1ZHI_WZ.pdb, 1Z1A_Z.pdb, 1M4Z_W.pdb
#   Created configs/config_abinitio.cfg
# Processing unit: 2A5T
#   Found: 2A5T_WZ.pdb, 2A5S_Z.pdb, 1Y20_W.pdb
#   Created configs/config_abinitio.cfg
# Processing unit: 2AJF
#   Found: 2AJF_WZ.pdb, 2GHV_Z.pdb, 1R42_W.pdb
#   Created configs/config_abinitio.cfg
# Processing unit: 2C0L
#   Found: 2C0L_WZ.pdb, 1C44_Z.pdb, 1FCH_W.pdb
#   Created configs/config_abinitio.cfg
# Processing unit: 2YVJ
#   Found: 2YVJ_WZ.pdb, 2E4P_Z.pdb, 2YVF_W.pdb
#   Created configs/config_abinitio.cfg
# Processing unit: 3PC8
#   Found: 3PC8_WZ.pdb, 3PC7_Z.pdb, 3PC6_W.pdb
#   Created configs/config_abinitio.cfg
# Processing unit: 4H03
#   Found: 4H03_WZ.pdb, 1IJJ_Z.pdb, 1GIQ_W.pdb
#   Created configs/config_abinitio.cfg
#
# Done!
# Success!
# ----------------------------------------
# Executing: python scripts_oracle/true_interface_restraints.py
# Root directory: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units
# Searching for subdirectories...
#
# Found 12 subdirectories.
#
# ================================================================================
#
# Processing: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/1JK9
# Input file : /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/1JK9/contacts/1JK9_WZ_1QUP_W_2JCW_Z_targetPairs.tsv
# Created directory: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/1JK9/tbls
# Output file: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/1JK9/tbls/ti.tbl
# Parameters : dist=10.0, d_minus=6.0, d_plus=2.0
# Success! HADDOCK restraints saved to '/orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/1JK9/tbls/ti.tbl'.
#
# Processing: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/1KXP
# Input file : /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/1KXP/contacts/1KXP_WZ_1IJJ_W_1KW2_Z_targetPairs.tsv
# Created directory: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/1KXP/tbls
# Output file: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/1KXP/tbls/ti.tbl
# Parameters : dist=10.0, d_minus=6.0, d_plus=2.0
# Success! HADDOCK restraints saved to '/orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/1KXP/tbls/ti.tbl'.
#
# Processing: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/1US7
# Input file : /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/1US7/contacts/1US7_WZ_2FXS_W_2W0G_Z_targetPairs.tsv
# Created directory: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/1US7/tbls
# Output file: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/1US7/tbls/ti.tbl
# Parameters : dist=10.0, d_minus=6.0, d_plus=2.0
# Success! HADDOCK restraints saved to '/orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/1US7/tbls/ti.tbl'.
#
# Processing: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/1Z5Y
# Input file : /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/1Z5Y/contacts/1Z5Y_WZ_1L6P_W_2B1K_Z_targetPairs.tsv
# Created directory: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/1Z5Y/tbls
# Output file: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/1Z5Y/tbls/ti.tbl
# Parameters : dist=10.0, d_minus=6.0, d_plus=2.0
# Success! HADDOCK restraints saved to '/orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/1Z5Y/tbls/ti.tbl'.
#
# Processing: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/1ZHH
# Input file : /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/1ZHH/contacts/1ZHH_WZ_1JX6_W_2HJE_Z_targetPairs.tsv
# Created directory: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/1ZHH/tbls
# Output file: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/1ZHH/tbls/ti.tbl
# Parameters : dist=10.0, d_minus=6.0, d_plus=2.0
# Success! HADDOCK restraints saved to '/orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/1ZHH/tbls/ti.tbl'.
#
# Processing: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/1ZHI
# Input file : /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/1ZHI/contacts/1ZHI_WZ_1M4Z_W_1Z1A_Z_targetPairs.tsv
# Created directory: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/1ZHI/tbls
# Output file: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/1ZHI/tbls/ti.tbl
# Parameters : dist=10.0, d_minus=6.0, d_plus=2.0
# Success! HADDOCK restraints saved to '/orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/1ZHI/tbls/ti.tbl'.
#
# Processing: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/2A5T
# Input file : /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/2A5T/contacts/2A5T_WZ_1Y20_W_2A5S_Z_targetPairs.tsv
# Created directory: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/2A5T/tbls
# Output file: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/2A5T/tbls/ti.tbl
# Parameters : dist=10.0, d_minus=6.0, d_plus=2.0
# Success! HADDOCK restraints saved to '/orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/2A5T/tbls/ti.tbl'.
#
# Processing: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/2AJF
# Input file : /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/2AJF/contacts/2AJF_WZ_1R42_W_2GHV_Z_targetPairs.tsv
# Created directory: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/2AJF/tbls
# Output file: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/2AJF/tbls/ti.tbl
# Parameters : dist=10.0, d_minus=6.0, d_plus=2.0
# Success! HADDOCK restraints saved to '/orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/2AJF/tbls/ti.tbl'.
#
# Processing: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/2C0L
# Input file : /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/2C0L/contacts/2C0L_WZ_1FCH_W_1C44_Z_targetPairs.tsv
# Created directory: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/2C0L/tbls
# Output file: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/2C0L/tbls/ti.tbl
# Parameters : dist=10.0, d_minus=6.0, d_plus=2.0
# Success! HADDOCK restraints saved to '/orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/2C0L/tbls/ti.tbl'.
#
# Processing: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/2YVJ
# Input file : /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/2YVJ/contacts/2YVJ_WZ_2YVF_W_2E4P_Z_targetPairs.tsv
# Created directory: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/2YVJ/tbls
# Output file: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/2YVJ/tbls/ti.tbl
# Parameters : dist=10.0, d_minus=6.0, d_plus=2.0
# Success! HADDOCK restraints saved to '/orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/2YVJ/tbls/ti.tbl'.
#
# Processing: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/3PC8
# Input file : /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/3PC8/contacts/3PC8_WZ_3PC6_W_3PC7_Z_targetPairs.tsv
# Created directory: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/3PC8/tbls
# Output file: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/3PC8/tbls/ti.tbl
# Parameters : dist=10.0, d_minus=6.0, d_plus=2.0
# Success! HADDOCK restraints saved to '/orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/3PC8/tbls/ti.tbl'.
#
# Processing: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/4H03
# Input file : /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/4H03/contacts/4H03_WZ_1GIQ_W_1IJJ_Z_targetPairs.tsv
# Created directory: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/4H03/tbls
# Output file: /orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/4H03/tbls/ti.tbl
# Parameters : dist=10.0, d_minus=6.0, d_plus=2.0
# Success! HADDOCK restraints saved to '/orfeo/cephfs/scratch/area/ssenci/senci_projects/LASTRUN/ESM3-PPISites/haddock_evaluation/data/haddock_units/4H03/tbls/ti.tbl'.
#
# ================================================================================
#
# Summary: Successfully processed 12/12 directories.
# Success!
# ----------------------------------------
# Executing: python scripts_oracle/compile_oracle_configs.py
# Processing unit: 1JK9
#   Found: 1JK9_WZ.pdb, 2JCW_Z.pdb, 1QUP_W.pdb
#   Created configs/config_oracle.cfg
# Processing unit: 1KXP
#   Found: 1KXP_WZ.pdb, 1KW2_Z.pdb, 1IJJ_W.pdb
#   Created configs/config_oracle.cfg
# Processing unit: 1US7
#   Found: 1US7_WZ.pdb, 2W0G_Z.pdb, 2FXS_W.pdb
#   Created configs/config_oracle.cfg
# Processing unit: 1Z5Y
#   Found: 1Z5Y_WZ.pdb, 2B1K_Z.pdb, 1L6P_W.pdb
#   Created configs/config_oracle.cfg
# Processing unit: 1ZHH
#   Found: 1ZHH_WZ.pdb, 2HJE_Z.pdb, 1JX6_W.pdb
#   Created configs/config_oracle.cfg
# Processing unit: 1ZHI
#   Found: 1ZHI_WZ.pdb, 1Z1A_Z.pdb, 1M4Z_W.pdb
#   Created configs/config_oracle.cfg
# Processing unit: 2A5T
#   Found: 2A5T_WZ.pdb, 2A5S_Z.pdb, 1Y20_W.pdb
#   Created configs/config_oracle.cfg
# Processing unit: 2AJF
#   Found: 2AJF_WZ.pdb, 2GHV_Z.pdb, 1R42_W.pdb
#   Created configs/config_oracle.cfg
# Processing unit: 2C0L
#   Found: 2C0L_WZ.pdb, 1C44_Z.pdb, 1FCH_W.pdb
#   Created configs/config_oracle.cfg
# Processing unit: 2YVJ
#   Found: 2YVJ_WZ.pdb, 2E4P_Z.pdb, 2YVF_W.pdb
#   Created configs/config_oracle.cfg
# Processing unit: 3PC8
#   Found: 3PC8_WZ.pdb, 3PC7_Z.pdb, 3PC6_W.pdb
#   Created configs/config_oracle.cfg
# Processing unit: 4H03
#   Found: 4H03_WZ.pdb, 1IJJ_Z.pdb, 1GIQ_W.pdb
#   Created configs/config_oracle.cfg
#
# Done!
# Success!
# ----------------------------------------
# Executing: python scripts_eval/inferenceESM3.py
#
# ==================================================
# Running inference with seed: 42
# ==================================================
# Model: big_model
# Dataset: BioLiP-3693
# Node: thin008.hpc.rd.areasciencepark.it
# Output: inference_results/db5_results.csv
# Saved inference results to: inference_results/db5_results.csv
# Success!
# ----------------------------------------
# Executing: python scripts_eval/PATCHES.py
# Success!
# ----------------------------------------
# Executing: python scripts_eval/PAIRING.py
# Created configuration file at: data/haddock_units/1JK9/configs/patches_1_1_0.cfg
# Created configuration file at: data/haddock_units/1JK9/configs/patches_1_1_1.cfg
# Created configuration file at: data/haddock_units/1JK9/configs/patches_1_0_0.cfg
# Created configuration file at: data/haddock_units/1JK9/configs/patches_1_0_1.cfg
# Created configuration file at: data/haddock_units/1JK9/configs/patches_0_1_0.cfg
# Created configuration file at: data/haddock_units/1JK9/configs/patches_0_1_1.cfg
# Created configuration file at: data/haddock_units/1JK9/configs/patches_0_0_0.cfg
# Created configuration file at: data/haddock_units/1JK9/configs/patches_0_0_1.cfg
# Created configuration file at: data/haddock_units/1KXP/configs/patches_0_0_0.cfg
# Created configuration file at: data/haddock_units/1KXP/configs/patches_0_0_1.cfg
# Created configuration file at: data/haddock_units/1KXP/configs/patches_0_1_0.cfg
# Created configuration file at: data/haddock_units/1KXP/configs/patches_0_1_1.cfg
# Created configuration file at: data/haddock_units/1KXP/configs/patches_1_0_0.cfg
# Created configuration file at: data/haddock_units/1KXP/configs/patches_1_0_1.cfg
# Created configuration file at: data/haddock_units/1KXP/configs/patches_1_1_0.cfg
# Created configuration file at: data/haddock_units/1KXP/configs/patches_1_1_1.cfg
# Created configuration file at: data/haddock_units/1US7/configs/patches_1_2_0.cfg
# Created configuration file at: data/haddock_units/1US7/configs/patches_1_2_1.cfg
# Created configuration file at: data/haddock_units/1US7/configs/patches_1_1_0.cfg
# Created configuration file at: data/haddock_units/1US7/configs/patches_1_1_1.cfg
# Created configuration file at: data/haddock_units/1US7/configs/patches_1_0_0.cfg
# Created configuration file at: data/haddock_units/1US7/configs/patches_1_0_1.cfg
# Created configuration file at: data/haddock_units/1US7/configs/patches_0_2_0.cfg
# Created configuration file at: data/haddock_units/1US7/configs/patches_0_2_1.cfg
# Created configuration file at: data/haddock_units/1US7/configs/patches_0_1_0.cfg
# Created configuration file at: data/haddock_units/1US7/configs/patches_0_1_1.cfg
# Created configuration file at: data/haddock_units/1US7/configs/patches_0_0_0.cfg
# Created configuration file at: data/haddock_units/1US7/configs/patches_0_0_1.cfg
# Created configuration file at: data/haddock_units/1Z5Y/configs/patches_1_1_0.cfg
# Created configuration file at: data/haddock_units/1Z5Y/configs/patches_1_1_1.cfg
# Created configuration file at: data/haddock_units/1Z5Y/configs/patches_1_0_0.cfg
# Created configuration file at: data/haddock_units/1Z5Y/configs/patches_1_0_1.cfg
# Created configuration file at: data/haddock_units/1Z5Y/configs/patches_2_1_0.cfg
# Created configuration file at: data/haddock_units/1Z5Y/configs/patches_2_1_1.cfg
# Created configuration file at: data/haddock_units/1Z5Y/configs/patches_2_0_0.cfg
# Created configuration file at: data/haddock_units/1Z5Y/configs/patches_2_0_1.cfg
# Created configuration file at: data/haddock_units/1Z5Y/configs/patches_0_1_0.cfg
# Created configuration file at: data/haddock_units/1Z5Y/configs/patches_0_1_1.cfg
# Created configuration file at: data/haddock_units/1Z5Y/configs/patches_0_0_0.cfg
# Created configuration file at: data/haddock_units/1Z5Y/configs/patches_0_0_1.cfg
# Created configuration file at: data/haddock_units/1ZHH/configs/patches_1_0_0.cfg
# Created configuration file at: data/haddock_units/1ZHH/configs/patches_1_0_1.cfg
# Created configuration file at: data/haddock_units/1ZHH/configs/patches_1_2_0.cfg
# Created configuration file at: data/haddock_units/1ZHH/configs/patches_1_2_1.cfg
# Created configuration file at: data/haddock_units/1ZHH/configs/patches_1_1_0.cfg
# Created configuration file at: data/haddock_units/1ZHH/configs/patches_1_1_1.cfg
# Created configuration file at: data/haddock_units/1ZHH/configs/patches_0_0_0.cfg
# Created configuration file at: data/haddock_units/1ZHH/configs/patches_0_0_1.cfg
# Created configuration file at: data/haddock_units/1ZHH/configs/patches_0_2_0.cfg
# Created configuration file at: data/haddock_units/1ZHH/configs/patches_0_2_1.cfg
# Created configuration file at: data/haddock_units/1ZHH/configs/patches_0_1_0.cfg
# Created configuration file at: data/haddock_units/1ZHH/configs/patches_0_1_1.cfg
# Created configuration file at: data/haddock_units/1ZHI/configs/patches_0_0_0.cfg
# Created configuration file at: data/haddock_units/1ZHI/configs/patches_0_0_1.cfg
# Created configuration file at: data/haddock_units/1ZHI/configs/patches_1_0_0.cfg
# Created configuration file at: data/haddock_units/1ZHI/configs/patches_1_0_1.cfg
# Created configuration file at: data/haddock_units/2A5T/configs/patches_1_1_0.cfg
# Created configuration file at: data/haddock_units/2A5T/configs/patches_1_1_1.cfg
# Created configuration file at: data/haddock_units/2A5T/configs/patches_1_0_0.cfg
# Created configuration file at: data/haddock_units/2A5T/configs/patches_1_0_1.cfg
# Created configuration file at: data/haddock_units/2A5T/configs/patches_0_1_0.cfg
# Created configuration file at: data/haddock_units/2A5T/configs/patches_0_1_1.cfg
# Created configuration file at: data/haddock_units/2A5T/configs/patches_0_0_0.cfg
# Created configuration file at: data/haddock_units/2A5T/configs/patches_0_0_1.cfg
# Created configuration file at: data/haddock_units/2AJF/configs/patches_1_1_0.cfg
# Created configuration file at: data/haddock_units/2AJF/configs/patches_1_1_1.cfg
# Created configuration file at: data/haddock_units/2AJF/configs/patches_1_0_0.cfg
# Created configuration file at: data/haddock_units/2AJF/configs/patches_1_0_1.cfg
# Created configuration file at: data/haddock_units/2AJF/configs/patches_1_2_0.cfg
# Created configuration file at: data/haddock_units/2AJF/configs/patches_1_2_1.cfg
# Created configuration file at: data/haddock_units/2AJF/configs/patches_0_1_0.cfg
# Created configuration file at: data/haddock_units/2AJF/configs/patches_0_1_1.cfg
# Created configuration file at: data/haddock_units/2AJF/configs/patches_0_0_0.cfg
# Created configuration file at: data/haddock_units/2AJF/configs/patches_0_0_1.cfg
# Created configuration file at: data/haddock_units/2AJF/configs/patches_0_2_0.cfg
# Created configuration file at: data/haddock_units/2AJF/configs/patches_0_2_1.cfg
# Created configuration file at: data/haddock_units/2C0L/configs/patches_1_0_0.cfg
# Created configuration file at: data/haddock_units/2C0L/configs/patches_1_0_1.cfg
# Created configuration file at: data/haddock_units/2C0L/configs/patches_1_1_0.cfg
# Created configuration file at: data/haddock_units/2C0L/configs/patches_1_1_1.cfg
# Created configuration file at: data/haddock_units/2C0L/configs/patches_0_0_0.cfg
# Created configuration file at: data/haddock_units/2C0L/configs/patches_0_0_1.cfg
# Created configuration file at: data/haddock_units/2C0L/configs/patches_0_1_0.cfg
# Created configuration file at: data/haddock_units/2C0L/configs/patches_0_1_1.cfg
# Created configuration file at: data/haddock_units/2YVJ/configs/patches_0_0_0.cfg
# Created configuration file at: data/haddock_units/2YVJ/configs/patches_0_0_1.cfg
# Created configuration file at: data/haddock_units/2YVJ/configs/patches_0_1_0.cfg
# Created configuration file at: data/haddock_units/2YVJ/configs/patches_0_1_1.cfg
# Created configuration file at: data/haddock_units/3PC8/configs/patches_0_1_0.cfg
# Created configuration file at: data/haddock_units/3PC8/configs/patches_0_1_1.cfg
# Created configuration file at: data/haddock_units/3PC8/configs/patches_0_0_0.cfg
# Created configuration file at: data/haddock_units/3PC8/configs/patches_0_0_1.cfg
# Created configuration file at: data/haddock_units/3PC8/configs/patches_0_2_0.cfg
# Created configuration file at: data/haddock_units/3PC8/configs/patches_0_2_1.cfg
# Created configuration file at: data/haddock_units/3PC8/configs/patches_1_1_0.cfg
# Created configuration file at: data/haddock_units/3PC8/configs/patches_1_1_1.cfg
# Created configuration file at: data/haddock_units/3PC8/configs/patches_1_0_0.cfg
# Created configuration file at: data/haddock_units/3PC8/configs/patches_1_0_1.cfg
# Created configuration file at: data/haddock_units/3PC8/configs/patches_1_2_0.cfg
# Created configuration file at: data/haddock_units/3PC8/configs/patches_1_2_1.cfg
# Created configuration file at: data/haddock_units/4H03/configs/patches_1_2_0.cfg
# Created configuration file at: data/haddock_units/4H03/configs/patches_1_2_1.cfg
# Created configuration file at: data/haddock_units/4H03/configs/patches_1_1_0.cfg
# Created configuration file at: data/haddock_units/4H03/configs/patches_1_1_1.cfg
# Created configuration file at: data/haddock_units/4H03/configs/patches_1_0_0.cfg
# Created configuration file at: data/haddock_units/4H03/configs/patches_1_0_1.cfg
# Created configuration file at: data/haddock_units/4H03/configs/patches_0_2_0.cfg
# Created configuration file at: data/haddock_units/4H03/configs/patches_0_2_1.cfg
# Created configuration file at: data/haddock_units/4H03/configs/patches_0_1_0.cfg
# Created configuration file at: data/haddock_units/4H03/configs/patches_0_1_1.cfg
# Created configuration file at: data/haddock_units/4H03/configs/patches_0_0_0.cfg
# Created configuration file at: data/haddock_units/4H03/configs/patches_0_0_1.cfg
# Success!
# ----------------------------------------
# Pipeline completed successfully!
